# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
Train_data = pd.read_csv('used_car_train_20200313.csv', sep=' ')
Test_data = pd.read_csv('used_car_testB_20200421.csv', sep=' ')

# %%
Train_data.head()
# Out:
#    SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  power  \
# 0       0     736  20040402   30.0      6       1.0       0.0      0.0     60
# 1       1    2262  20030301   40.0      1       2.0       0.0      0.0      0
# 2       2   14874  20040403  115.0     15       1.0       0.0      0.0    163
# 3       3   71865  19960908  109.0     10       0.0       0.0      1.0    193
# 4       4  111080  20120103  110.0      5       1.0       0.0      0.0     68
#
#    kilometer notRepairedDamage  regionCode  seller  offerType  creatDate  \
# 0       12.5               0.0        1046       0          0   20160404
# 1       15.0                 -        4366       0          0   20160309
# 2       12.5               0.0        2806       0          0   20160402
# 3       15.0               0.0         434       0          0   20160312
# 4        5.0               0.0        6977       0          0   20160313
#
# ...

# %% [markdown]
# ### task 2

# %%
Train_data.columns
# Out:
# Index(['SaleID', 'name', 'regDate', 'model', 'brand', 'bodyType', 'fuelType',
#        'gearbox', 'power', 'kilometer', 'notRepairedDamage', 'regionCode',
#        'seller', 'offerType', 'creatDate', 'price', 'v_0', 'v_1', 'v_2', 'v_3',
#        'v_4', 'v_5', 'v_6', 'v_7', 'v_8', 'v_9', 'v_10', 'v_11', 'v_12',
#        'v_13', 'v_14', 'regDate1'],
#       dtype='object')

# %%
Train_data.dtypes
# Out:
# SaleID                 int64
# name                   int64
# regDate                int64
# model                float64
# brand                  int64
# bodyType             float64
# fuelType             float64
# gearbox              float64
# power                  int64
# kilometer            float64
# notRepairedDamage     object
# regionCode             int64
# seller                 int64
# offerType              int64
# creatDate              int64
# price                  int64
# v_0                  float64
# v_1                  float64
# v_2                  float64
# v_3                  float64
# v_4                  float64
# v_5                  float64
# v_6                  float64
# v_7                  float64
# v_8                  float64
# v_9                  float64
# v_10                 float64
# v_11                 float64
# v_12                 float64
# v_13                 float64
# v_14                 float64
# dtype: object

# %%
Train_data.hist(figsize=(15, 15))
# Out:
# d:\python\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# d:\python\lib\site-packages\pandas\plotting\_matplotlib\tools.py:298: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# d:\python\lib\site-packages\pandas\plotting\_matplotlib\tools.py:304: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
Train_data.corr()['price']
# Out:
# SaleID       -0.001043
# name          0.002030
# regDate       0.611959
# model         0.136983
# brand        -0.043799
# bodyType      0.241303
# fuelType      0.200536
# gearbox       0.329075
# power         0.219834
# kilometer    -0.440519
# regionCode    0.014036
# seller       -0.002004
# offerType          NaN
# creatDate     0.002955
# price         1.000000
# v_0           0.628397
# v_1           0.060914
# v_2           0.085322
# v_3          -0.730946
# v_4          -0.147085
# v_5           0.164317
# v_6           0.068970
# v_7          -0.053024
# v_8           0.685798
# v_9          -0.206205
# v_10         -0.246175
# v_11         -0.275320
# v_12          0.692823
# v_13         -0.013993
# v_14          0.035911
# Name: price, dtype: float64

# %%
Train_data.corr()['price'].abs().sort_values(ascending=False)
# Out:
# price         1.000000
# v_3           0.730946
# v_12          0.692823
# v_8           0.685798
# v_0           0.628397
# regDate       0.611959
# kilometer     0.440519
# gearbox       0.329075
# v_11          0.275320
# v_10          0.246175
# bodyType      0.241303
# power         0.219834
# v_9           0.206205
# fuelType      0.200536
# v_5           0.164317
# v_4           0.147085
# model         0.136983
# v_2           0.085322
# v_6           0.068970
# v_1           0.060914
# v_7           0.053024
# brand         0.043799
# v_14          0.035911
# regionCode    0.014036
# v_13          0.013993
# creatDate     0.002955
# name          0.002030
# seller        0.002004
# SaleID        0.001043
# offerType          NaN
# Name: price, dtype: float64

# %%
import seaborn as sns

# %%
Train_data['v_3'].describe()
# Out:
# count    150000.000000
# mean          0.078833
# std           2.026514
# min          -7.275037
# 25%          -1.462580
# 50%           0.099722
# 75%           1.565838
# max           9.854702
# Name: v_3, dtype: float64

# %%
# Train_data['v_3'].plot(kind='box')
sns.boxplot(Train_data['v_3'])     ## 箱线图

# %%
## 密度图
sns.distplot(Train_data['v_3'])  ## 近乎正态分布

# %%
## 查看 v_3 字段与 目标字段的相关趋势分布
sns.scatterplot(Train_data['v_3'], Train_data['price'])   ## 与相关性指数对应呈现负相关趋势

# %%
sns.scatterplot(Train_data['v_12'], Train_data['price'])

# %%
sns.scatterplot(Train_data['v_8'], Train_data['price'])

# %%
Train_data['regDate1'] = Train_data['regDate'].apply(lambda x: str(x)[:4])
Train_data.head()
# Out:
#    SaleID    name   regDate  model  brand  bodyType  fuelType  gearbox  power  \
# 0       0     736  20040402   30.0      6       1.0       0.0      0.0     60
# 1       1    2262  20030301   40.0      1       2.0       0.0      0.0      0
# 2       2   14874  20040403  115.0     15       1.0       0.0      0.0    163
# 3       3   71865  19960908  109.0     10       0.0       0.0      1.0    193
# 4       4  111080  20120103  110.0      5       1.0       0.0      0.0     68
#
#    kilometer notRepairedDamage  regionCode  seller  offerType  creatDate  \
# 0       12.5               0.0        1046       0          0   20160404
# 1       15.0                 -        4366       0          0   20160309
# 2       12.5               0.0        2806       0          0   20160402
# 3       15.0               0.0         434       0          0   20160312
# 4        5.0               0.0        6977       0          0   20160313
#
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 7))
sns.boxplot(Train_data['regDate1'], Train_data['price'])

# %%
plt.figure(figsize=(12, 7))
sns.barplot(Train_data['regDate1'], Train_data['price'])   ## 正相关

# %% [markdown]
# ### task 3

# %%
Train_data['price'].describe()
# Out:
# count    150000.000000
# mean       5923.327333
# std        7501.998477
# min          11.000000
# 25%        1300.000000
# 50%        3250.000000
# 75%        7700.000000
# max       99999.000000
# Name: price, dtype: float64

# %%
sns.boxplot(Train_data['price'])

# %%
sns.distplot(Train_data['price'])

# %%
import numpy as np
sns.distplot(np.log(Train_data['price']))    ## 使用log转换
