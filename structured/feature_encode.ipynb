# %% [markdown]
# ### 特征编码

# %%
import pandas as pd
df = pd.DataFrame({
    'student_id': [1,2,3,4,5,6,7],
    'country': ['China', 'USA', 'UK', 'Japan', 'Korea', 'China', 'USA'],
    'education': ['Master', 'Bachelor', 'Bachelor', 'Master', 'PHD', 'PHD', 'Bachelor'],
    'target': [1, 0, 1, 0, 1, 0, 1]
})
df.head()
# Out:
#    student_id country education  target
# 0           1   China    Master       1
# 1           2     USA  Bachelor       0
# 2           3      UK  Bachelor       1
# 3           4   Japan    Master       0
# 4           5   Korea       PHD       1

# %% [markdown]
# ##### One-hot

# %%
pd.get_dummies(df, columns=['education'])
# Out:
#    student_id country  target  education_Bachelor  education_Master  \
# 0           1   China       1                   0                 1
# 1           2     USA       0                   1                 0
# 2           3      UK       1                   1                 0
# 3           4   Japan       0                   0                 1
# 4           5   Korea       1                   0                 0
# 5           6   China       0                   0                 0
# 6           7     USA       1                   1                 0
#
#    education_PHD
# 0              0
# 1              0
# 2              0
# 3              0
# 4              1
# 5              1
# 6              0

# %%
from sklearn.preprocessing import OneHotEncoder
one = OneHotEncoder()
one.fit_transform(df[['country']]).toarray()

# %% [markdown]
# ##### LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['country_LabelEncoder'] = le.fit_transform(df['country'])
df.head(10)

# %% [markdown]
# ##### Ordinal Encoding

# %%
df['education'] = df['education'].map(
                    {'Bachelor': 1, 
                    'Master': 2, 
                    'PHD': 3})
df.head(10)
# Out:
#    student_id country  education  target
# 0           1   China        NaN       1
# 1           2     USA        NaN       0
# 2           3      UK        NaN       1
# 3           4   Japan        NaN       0
# 4           5   Korea        NaN       1
# 5           6   China        NaN       0
# 6           7     USA        NaN       1

# %% [markdown]
# ##### BinaryEncoder

# %%
import category_encoders as ce
encoder = ce.BinaryEncoder(cols= ['country'])

pd.concat([df, encoder.fit_transform(df['country']).iloc[:, 1:]], axis=1)

# %% [markdown]
# ##### Frequency Encoding、Count Encoding

# %%
df['country_count'] = df['country'].map(df['country'].value_counts()) / len(df)
df.head(10)
# Out:
#    student_id country  education  target  country_count
# 0           1   China        NaN       1       0.285714
# 1           2     USA        NaN       0       0.285714
# 2           3      UK        NaN       1       0.142857
# 3           4   Japan        NaN       0       0.142857
# 4           5   Korea        NaN       1       0.142857
# 5           6   China        NaN       0       0.285714
# 6           7     USA        NaN       1       0.285714

# %% [markdown]
# ##### Mean/Target Encoding

# %%
df.groupby(['country'])['target'].mean()
df['country_target'] = df['country'].map(df.groupby(['country'])['target'].mean())
df.head(10)
# Out:
#    student_id country  education  target  country_count  country_target
# 0           1   China        NaN       1       0.285714             0.5
# 1           2     USA        NaN       0       0.285714             0.5
# 2           3      UK        NaN       1       0.142857             1.0
# 3           4   Japan        NaN       0       0.142857             0.0
# 4           5   Korea        NaN       1       0.142857             1.0
# 5           6   China        NaN       0       0.285714             0.5
# 6           7     USA        NaN       1       0.285714             0.5
