# %%
import codecs, glob, os
import numpy as np
import pandas as pd

import paddle.nn.functional as F
import paddle
import paddle.nn as nn
from paddle.io import DataLoader, Dataset
import paddle.optimizer as optim
from paddlenlp.data import Pad

import scipy.io as sio

# %%
train_mat = glob.glob('./train/*.mat')
train_mat.sort()
# train_mat = [sio.loadmat(x)['ecgdata'].reshape(1, 12, 5000) for x in train_mat]
train_mat = [sio.loadmat(x)['ecgdata'] for x in train_mat]

test_mat = glob.glob('./val/*.mat')
test_mat.sort()
# test_mat = [sio.loadmat(x)['ecgdata'].reshape(1, 12, 5000) for x in test_mat]
test_mat = [sio.loadmat(x)['ecgdata'] for x in test_mat]

train_df = pd.read_csv('trainreference.csv')
train_df['tag'] = train_df['tag'].astype(np.float32)

# %%
class MyDataset(Dataset):
    def __init__(self, mat, label, mat_dim=5000):
        super(MyDataset, self).__init__()
        self.mat = mat
        self.label = label
        self.mat_dim = mat_dim

    def __len__(self):
        return len(self.mat)

    def __getitem__(self, index):
        # idx = np.random.randint(0, 5000-self.mat_dim)
        # idy = np.random.choice(range(12), 9)
        return paddle.to_tensor(self.mat[index][:, 0:self.mat_dim]), self.label[index]

# %%
class TextCNN_bak(paddle.nn.Layer):
    def __init__(self, kernel_num=30, kernel_size=[3, 4, 5], dropout=0.5):
        super(TextCNN, self).__init__()
        self.kernel_num = kernel_num
        self.kernel_size = kernel_size
        self.dropout = dropout

        self.convs = nn.LayerList([nn.Conv2D(1, self.kernel_num, (kernel_size_, 3000)) 
                for kernel_size_ in self.kernel_size])
        self.dropout = nn.Dropout(self.dropout)
        self.linear = nn.Linear(3 * self.kernel_num, 1)

    def forward(self, x):
        convs = [nn.ReLU()(conv(x)).squeeze(3) for conv in self.convs]
        pool_out = [nn.MaxPool1D(block.shape[2])(block).squeeze(2) for block in convs]
        pool_out = paddle.concat(pool_out, 1)
        logits = self.linear(pool_out)

        return logits

class TextCNN(nn.Layer):
    def __init__(self):
        super(TextCNN, self).__init__()
        # input 
        self.conv1 = nn.Conv1D(12, 10, 50)
        self.conv2 = nn.Conv1D(12, 10, 200)
        self.conv3 = nn.Conv1D(12, 10, 500)
        self.conv4 = nn.Conv1D(12, 10, 1000)
        # self.pooling = nn.MaxPool2D((1, 200))
        self.pooling = nn.MaxPool1D(200)
        self.fc1 = nn.Linear(900, 64)
        self.fc2 = nn.Linear(64, 1)

    def forward(self, x):
        batch_size = x.shape[0]
        
        out1 = self.pooling(F.relu(self.conv1(x)))
        out2 = self.pooling(F.relu(self.conv2(x)))
        out3 = self.pooling(F.relu(self.conv3(x)))
        out4 = self.pooling(F.relu(self.conv4(x)))

        # # out = torch.cat([out1, out2, out3, out4], 2)  
        out = paddle.concat([out1, out2, out3, out4], 2)
        # out = out.view(batch_size, -1)
        out = paddle.reshape(out, [batch_size, -1])
        out = self.fc1(out)
        out = F.relu(out)
        out = F.dropout(out, p=0.5)
        out = self.fc2(out)

        return out

# %%
model = TextCNN()

BATCH_SIZE = 30
EPOCHS = 200
LEARNING_RATE = 0.0001
device = paddle.device.get_device()
print(device)
# Out:
# W1127 17:49:23.307835   180 device_context.cc:404] Please NOTE: device: 0, GPU Compute Capability: 7.0, Driver API Version: 10.1, Runtime API Version: 10.1
# W1127 17:49:23.313158   180 device_context.cc:422] device: 0, cuDNN Version: 7.6.
# gpu:0

# %%
# paddle.summary(model, (64, 1, 9, 3000))

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=10)

# %%
fold_idx = 0
for tr_idx, val_idx in skf.split(train_mat, train_df['tag'].values):
    Train_Loader = DataLoader(MyDataset(np.array(train_mat)[tr_idx], paddle.to_tensor(train_df['tag'].values[tr_idx])), batch_size=BATCH_SIZE, shuffle=True)
    Val_Loader = DataLoader(MyDataset(np.array(train_mat)[val_idx], paddle.to_tensor(train_df['tag'].values[val_idx])), batch_size=BATCH_SIZE, shuffle=True)
    model = TextCNN()

    optimizer = optim.Adam(parameters=model.parameters(), learning_rate=LEARNING_RATE)
    criterion = nn.BCEWithLogitsLoss()

    Test_best_Acc = 0
    for epoch in range(0, EPOCHS):
        Train_Loss, Test_Loss = [], []
        Train_Acc, Test_Acc = [], []
        model.train()
        for i, (x, y) in enumerate(Train_Loader):
            if device == 'gpu':
                x = x.cuda()
                y = y.cuda()
            # print(x.shape)
            pred = model(x)
            loss = criterion(pred, y)
            Train_Loss.append(loss.item())

            pred = (paddle.nn.functional.sigmoid(pred)>0.5).astype(int)
            Train_Acc.append((pred.numpy() == y.numpy()).mean())
            loss.backward()
            optimizer.step()
            optimizer.clear_grad()
        model.eval()

        for i, (x, y) in enumerate(Val_Loader):
            if device == 'gpu':
                x = x.cuda()
                y = y.cuda()
            
            pred = model(x)
            Test_Loss.append(criterion(pred, y).item())
            pred = (paddle.nn.functional.sigmoid(pred)>0.5).astype(int)
            Test_Acc.append((pred.numpy() == y.numpy()).mean())
        
        if epoch % 10 == 0:
            print(
                "Epoch: [{}/{}] TrainLoss/TestLoss: {:.4f}/{:.4f} TrainAcc/TestAcc: {:.4f}/{:.4f}".format( \
                epoch + 1, EPOCHS, \
                np.mean(Train_Loss), np.mean(Test_Loss), \
                np.mean(Train_Acc), np.mean(Test_Acc) \
                )
            )

        if Test_best_Acc < np.mean(Test_Acc):
            print(f'Fold {fold_idx} Acc imporve from {Test_best_Acc} to {np.mean(Test_Acc)} Save Model...')
            paddle.save(model.state_dict(), f"model_{fold_idx}.pdparams")
            Test_best_Acc = np.mean(Test_Acc)

    fold_idx += 1
# Out:
# Epoch: [1/200] TrainLoss/TestLoss: 1.1079/0.9065 TrainAcc/TestAcc: 0.5292/0.4722
# Fold 0 Acc imporve from 0 to 0.47222222222222215 Save Model...
# Fold 0 Acc imporve from 0.47222222222222215 to 0.5222222222222223 Save Model...
# Fold 0 Acc imporve from 0.5222222222222223 to 0.5944444444444444 Save Model...
# Fold 0 Acc imporve from 0.5944444444444444 to 0.6499999999999999 Save Model...
# Fold 0 Acc imporve from 0.6499999999999999 to 0.6555555555555556 Save Model...
# Fold 0 Acc imporve from 0.6555555555555556 to 0.7444444444444445 Save Model...
# Fold 0 Acc imporve from 0.7444444444444445 to 0.7611111111111111 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5972/0.5881 TrainAcc/TestAcc: 0.6972/0.6889
# Fold 0 Acc imporve from 0.7611111111111111 to 0.7888888888888889 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4133/0.5311 TrainAcc/TestAcc: 0.8208/0.7444
# Fold 0 Acc imporve from 0.7888888888888889 to 0.8333333333333335 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3384/0.5149 TrainAcc/TestAcc: 0.8701/0.7778
# Epoch: [41/200] TrainLoss/TestLoss: 0.3069/0.5110 TrainAcc/TestAcc: 0.8806/0.8222
# Epoch: [51/200] TrainLoss/TestLoss: 0.2557/0.6237 TrainAcc/TestAcc: 0.9062/0.8222
# Fold 0 Acc imporve from 0.8333333333333335 to 0.8666666666666667 Save Model...
# Epoch: [61/200] TrainLoss/TestLoss: 0.2374/0.3960 TrainAcc/TestAcc: 0.9042/0.8444
# Epoch: [71/200] TrainLoss/TestLoss: 0.2033/0.5081 TrainAcc/TestAcc: 0.9271/0.7889
# Epoch: [81/200] TrainLoss/TestLoss: 0.1715/0.7631 TrainAcc/TestAcc: 0.9424/0.7667
# Epoch: [91/200] TrainLoss/TestLoss: 0.1455/0.7872 TrainAcc/TestAcc: 0.9438/0.7500
# Epoch: [101/200] TrainLoss/TestLoss: 0.1007/0.6729 TrainAcc/TestAcc: 0.9660/0.7833
# Epoch: [111/200] TrainLoss/TestLoss: 0.0949/0.6322 TrainAcc/TestAcc: 0.9674/0.8222
# Epoch: [121/200] TrainLoss/TestLoss: 0.0735/0.6482 TrainAcc/TestAcc: 0.9778/0.8111
# Epoch: [131/200] TrainLoss/TestLoss: 0.1620/0.6999 TrainAcc/TestAcc: 0.9549/0.7889
# Epoch: [141/200] TrainLoss/TestLoss: 0.0728/0.8416 TrainAcc/TestAcc: 0.9715/0.8444
# Epoch: [151/200] TrainLoss/TestLoss: 0.1039/0.7572 TrainAcc/TestAcc: 0.9667/0.8000
# Epoch: [161/200] TrainLoss/TestLoss: 0.0438/0.8318 TrainAcc/TestAcc: 0.9868/0.8389
# Epoch: [171/200] TrainLoss/TestLoss: 0.1464/0.7608 TrainAcc/TestAcc: 0.9590/0.8000
# Epoch: [181/200] TrainLoss/TestLoss: 0.0459/0.6082 TrainAcc/TestAcc: 0.9868/0.8444
# Epoch: [191/200] TrainLoss/TestLoss: 0.0649/0.8946 TrainAcc/TestAcc: 0.9799/0.7944
# Epoch: [1/200] TrainLoss/TestLoss: 0.8451/0.7958 TrainAcc/TestAcc: 0.5014/0.4444
# Fold 1 Acc imporve from 0 to 0.4444444444444444 Save Model...
# Fold 1 Acc imporve from 0.4444444444444444 to 0.5388888888888889 Save Model...
# Fold 1 Acc imporve from 0.5388888888888889 to 0.6 Save Model...
# Fold 1 Acc imporve from 0.6 to 0.6166666666666666 Save Model...
# Fold 1 Acc imporve from 0.6166666666666666 to 0.6222222222222222 Save Model...
# Fold 1 Acc imporve from 0.6222222222222222 to 0.6222222222222223 Save Model...
# Fold 1 Acc imporve from 0.6222222222222223 to 0.6666666666666666 Save Model...
# Fold 1 Acc imporve from 0.6666666666666666 to 0.75 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5619/0.5573 TrainAcc/TestAcc: 0.7403/0.7056
# Fold 1 Acc imporve from 0.75 to 0.7666666666666667 Save Model...
# Fold 1 Acc imporve from 0.7666666666666667 to 0.7722222222222223 Save Model...
# Fold 1 Acc imporve from 0.7722222222222223 to 0.8166666666666665 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4222/0.4594 TrainAcc/TestAcc: 0.8181/0.7556
# Fold 1 Acc imporve from 0.8166666666666665 to 0.8500000000000001 Save Model...
# Fold 1 Acc imporve from 0.8500000000000001 to 0.9 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3460/0.3947 TrainAcc/TestAcc: 0.8604/0.8611
# Epoch: [41/200] TrainLoss/TestLoss: 0.3124/0.3836 TrainAcc/TestAcc: 0.8806/0.8556
# Epoch: [51/200] TrainLoss/TestLoss: 0.2685/0.3325 TrainAcc/TestAcc: 0.8986/0.8500
# Epoch: [61/200] TrainLoss/TestLoss: 0.2930/0.3970 TrainAcc/TestAcc: 0.9007/0.8111
# Epoch: [71/200] TrainLoss/TestLoss: 0.1915/0.3632 TrainAcc/TestAcc: 0.9229/0.8389
# Epoch: [81/200] TrainLoss/TestLoss: 0.2041/0.5791 TrainAcc/TestAcc: 0.9292/0.8000
# Epoch: [91/200] TrainLoss/TestLoss: 0.1361/0.4577 TrainAcc/TestAcc: 0.9486/0.8444
# Epoch: [101/200] TrainLoss/TestLoss: 0.1204/0.4652 TrainAcc/TestAcc: 0.9604/0.8500
# Epoch: [111/200] TrainLoss/TestLoss: 0.0926/0.5474 TrainAcc/TestAcc: 0.9694/0.8389
# Epoch: [121/200] TrainLoss/TestLoss: 0.0854/0.5484 TrainAcc/TestAcc: 0.9674/0.8500
# Epoch: [131/200] TrainLoss/TestLoss: 0.0777/0.3496 TrainAcc/TestAcc: 0.9715/0.8556
# Epoch: [141/200] TrainLoss/TestLoss: 0.0773/0.4320 TrainAcc/TestAcc: 0.9736/0.8556
# Epoch: [151/200] TrainLoss/TestLoss: 0.0568/0.7091 TrainAcc/TestAcc: 0.9806/0.8333
# Epoch: [161/200] TrainLoss/TestLoss: 0.0660/0.4930 TrainAcc/TestAcc: 0.9771/0.8667
# Epoch: [171/200] TrainLoss/TestLoss: 0.0806/0.5256 TrainAcc/TestAcc: 0.9785/0.8778
# Epoch: [181/200] TrainLoss/TestLoss: 0.0369/0.6115 TrainAcc/TestAcc: 0.9882/0.8444
# Epoch: [191/200] TrainLoss/TestLoss: 0.0626/0.7299 TrainAcc/TestAcc: 0.9757/0.8389
# Epoch: [1/200] TrainLoss/TestLoss: 0.8717/1.2169 TrainAcc/TestAcc: 0.5250/0.4222
# Fold 2 Acc imporve from 0 to 0.4222222222222222 Save Model...
# Fold 2 Acc imporve from 0.4222222222222222 to 0.5277777777777778 Save Model...
# Fold 2 Acc imporve from 0.5277777777777778 to 0.5888888888888889 Save Model...
# Fold 2 Acc imporve from 0.5888888888888889 to 0.6166666666666667 Save Model...
# Fold 2 Acc imporve from 0.6166666666666667 to 0.6666666666666665 Save Model...
# Fold 2 Acc imporve from 0.6666666666666665 to 0.6722222222222222 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5038/0.6910 TrainAcc/TestAcc: 0.7514/0.6944
# Fold 2 Acc imporve from 0.6722222222222222 to 0.6944444444444445 Save Model...
# Fold 2 Acc imporve from 0.6944444444444445 to 0.7000000000000001 Save Model...
# Fold 2 Acc imporve from 0.7000000000000001 to 0.7555555555555555 Save Model...
# Fold 2 Acc imporve from 0.7555555555555555 to 0.7833333333333333 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.3805/1.2554 TrainAcc/TestAcc: 0.8340/0.7222
# Fold 2 Acc imporve from 0.7833333333333333 to 0.7999999999999999 Save Model...
# Fold 2 Acc imporve from 0.7999999999999999 to 0.8055555555555557 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3288/0.6570 TrainAcc/TestAcc: 0.8563/0.8222
# Fold 2 Acc imporve from 0.8055555555555557 to 0.8222222222222223 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.2603/1.1540 TrainAcc/TestAcc: 0.8924/0.7889
# Epoch: [51/200] TrainLoss/TestLoss: 0.2113/1.0973 TrainAcc/TestAcc: 0.9160/0.8111
# Fold 2 Acc imporve from 0.8222222222222223 to 0.8277777777777778 Save Model...
# Fold 2 Acc imporve from 0.8277777777777778 to 0.8333333333333334 Save Model...
# Epoch: [61/200] TrainLoss/TestLoss: 0.2054/1.0983 TrainAcc/TestAcc: 0.9215/0.7778
# Fold 2 Acc imporve from 0.8333333333333334 to 0.8388888888888887 Save Model...
# Epoch: [71/200] TrainLoss/TestLoss: 0.1516/1.5389 TrainAcc/TestAcc: 0.9424/0.8222
# Fold 2 Acc imporve from 0.8388888888888887 to 0.8388888888888889 Save Model...
# Epoch: [81/200] TrainLoss/TestLoss: 0.1266/1.4477 TrainAcc/TestAcc: 0.9507/0.8167
# Fold 2 Acc imporve from 0.8388888888888889 to 0.8500000000000001 Save Model...
# Epoch: [91/200] TrainLoss/TestLoss: 0.1192/1.2721 TrainAcc/TestAcc: 0.9535/0.7889
# Epoch: [101/200] TrainLoss/TestLoss: 0.1379/2.9507 TrainAcc/TestAcc: 0.9535/0.8056
# Epoch: [111/200] TrainLoss/TestLoss: 0.0722/2.3874 TrainAcc/TestAcc: 0.9757/0.8222
# Epoch: [121/200] TrainLoss/TestLoss: 0.1066/1.9559 TrainAcc/TestAcc: 0.9618/0.8500
# Fold 2 Acc imporve from 0.8500000000000001 to 0.8555555555555556 Save Model...
# Epoch: [131/200] TrainLoss/TestLoss: 0.0609/2.0218 TrainAcc/TestAcc: 0.9750/0.7833
# Epoch: [141/200] TrainLoss/TestLoss: 0.0547/2.5269 TrainAcc/TestAcc: 0.9806/0.8111
# Epoch: [151/200] TrainLoss/TestLoss: 0.0518/2.6343 TrainAcc/TestAcc: 0.9799/0.7722
# Epoch: [161/200] TrainLoss/TestLoss: 0.0564/4.0665 TrainAcc/TestAcc: 0.9799/0.8000
# Epoch: [171/200] TrainLoss/TestLoss: 0.0489/2.8801 TrainAcc/TestAcc: 0.9792/0.7667
# Epoch: [181/200] TrainLoss/TestLoss: 0.0386/2.2202 TrainAcc/TestAcc: 0.9826/0.7722
# Epoch: [191/200] TrainLoss/TestLoss: 0.0263/2.6855 TrainAcc/TestAcc: 0.9951/0.7889
# Epoch: [1/200] TrainLoss/TestLoss: 0.7935/0.7435 TrainAcc/TestAcc: 0.5194/0.5167
# Fold 3 Acc imporve from 0 to 0.5166666666666666 Save Model...
# Fold 3 Acc imporve from 0.5166666666666666 to 0.5555555555555555 Save Model...
# Fold 3 Acc imporve from 0.5555555555555555 to 0.6444444444444444 Save Model...
# Fold 3 Acc imporve from 0.6444444444444444 to 0.6444444444444445 Save Model...
# Fold 3 Acc imporve from 0.6444444444444445 to 0.7055555555555556 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5419/0.6211 TrainAcc/TestAcc: 0.7271/0.6500
# Fold 3 Acc imporve from 0.7055555555555556 to 0.7333333333333334 Save Model...
# Fold 3 Acc imporve from 0.7333333333333334 to 0.7555555555555555 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.3952/0.5347 TrainAcc/TestAcc: 0.8257/0.7556
# Fold 3 Acc imporve from 0.7555555555555555 to 0.7666666666666667 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3450/0.6056 TrainAcc/TestAcc: 0.8583/0.6833
# Fold 3 Acc imporve from 0.7666666666666667 to 0.7777777777777778 Save Model...
# Fold 3 Acc imporve from 0.7777777777777778 to 0.7888888888888889 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.2787/0.4995 TrainAcc/TestAcc: 0.8882/0.7667
# Fold 3 Acc imporve from 0.7888888888888889 to 0.8111111111111112 Save Model...
# Epoch: [51/200] TrainLoss/TestLoss: 0.2711/0.5687 TrainAcc/TestAcc: 0.8972/0.7722
# Fold 3 Acc imporve from 0.8111111111111112 to 0.8388888888888889 Save Model...
# Epoch: [61/200] TrainLoss/TestLoss: 0.1990/0.5578 TrainAcc/TestAcc: 0.9278/0.7778
# Epoch: [71/200] TrainLoss/TestLoss: 0.1779/0.7813 TrainAcc/TestAcc: 0.9361/0.7389
# Epoch: [81/200] TrainLoss/TestLoss: 0.1832/0.7146 TrainAcc/TestAcc: 0.9340/0.7833
# Epoch: [91/200] TrainLoss/TestLoss: 0.1422/0.6012 TrainAcc/TestAcc: 0.9493/0.8000
# Epoch: [101/200] TrainLoss/TestLoss: 0.1494/0.8244 TrainAcc/TestAcc: 0.9500/0.7889
# Epoch: [111/200] TrainLoss/TestLoss: 0.1247/0.7912 TrainAcc/TestAcc: 0.9569/0.7722
# Epoch: [121/200] TrainLoss/TestLoss: 0.0998/0.9312 TrainAcc/TestAcc: 0.9660/0.8278
# Epoch: [131/200] TrainLoss/TestLoss: 0.0744/0.6182 TrainAcc/TestAcc: 0.9771/0.8278
# Epoch: [141/200] TrainLoss/TestLoss: 0.0592/0.6083 TrainAcc/TestAcc: 0.9785/0.8333
# Epoch: [151/200] TrainLoss/TestLoss: 0.0618/0.8776 TrainAcc/TestAcc: 0.9764/0.7889
# Epoch: [161/200] TrainLoss/TestLoss: 0.0458/0.7876 TrainAcc/TestAcc: 0.9875/0.7944
# Fold 3 Acc imporve from 0.8388888888888889 to 0.8500000000000001 Save Model...
# Fold 3 Acc imporve from 0.8500000000000001 to 0.8555555555555555 Save Model...
# Epoch: [171/200] TrainLoss/TestLoss: 0.0719/0.6561 TrainAcc/TestAcc: 0.9736/0.8389
# Epoch: [181/200] TrainLoss/TestLoss: 0.0550/0.9280 TrainAcc/TestAcc: 0.9785/0.7889
# Epoch: [191/200] TrainLoss/TestLoss: 0.0544/0.7546 TrainAcc/TestAcc: 0.9819/0.8056
# Epoch: [1/200] TrainLoss/TestLoss: 0.8668/0.7913 TrainAcc/TestAcc: 0.5174/0.5000
# Fold 4 Acc imporve from 0 to 0.5 Save Model...
# Fold 4 Acc imporve from 0.5 to 0.5111111111111111 Save Model...
# Fold 4 Acc imporve from 0.5111111111111111 to 0.6555555555555556 Save Model...
# Fold 4 Acc imporve from 0.6555555555555556 to 0.6833333333333332 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5618/0.6421 TrainAcc/TestAcc: 0.7264/0.7000
# Fold 4 Acc imporve from 0.6833333333333332 to 0.6999999999999998 Save Model...
# Fold 4 Acc imporve from 0.6999999999999998 to 0.7166666666666667 Save Model...
# Fold 4 Acc imporve from 0.7166666666666667 to 0.7611111111111111 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4342/0.6112 TrainAcc/TestAcc: 0.8063/0.7333
# Epoch: [31/200] TrainLoss/TestLoss: 0.3540/0.6381 TrainAcc/TestAcc: 0.8611/0.7111
# Fold 4 Acc imporve from 0.7611111111111111 to 0.7722222222222221 Save Model...
# Fold 4 Acc imporve from 0.7722222222222221 to 0.7777777777777778 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.3133/0.6266 TrainAcc/TestAcc: 0.8861/0.7222
# Fold 4 Acc imporve from 0.7777777777777778 to 0.7888888888888889 Save Model...
# Fold 4 Acc imporve from 0.7888888888888889 to 0.7944444444444444 Save Model...
# Epoch: [51/200] TrainLoss/TestLoss: 0.2476/0.5452 TrainAcc/TestAcc: 0.9139/0.7611
# Fold 4 Acc imporve from 0.7944444444444444 to 0.7944444444444446 Save Model...
# Epoch: [61/200] TrainLoss/TestLoss: 0.2182/0.7295 TrainAcc/TestAcc: 0.9229/0.7444
# Fold 4 Acc imporve from 0.7944444444444446 to 0.8222222222222224 Save Model...
# Epoch: [71/200] TrainLoss/TestLoss: 0.1884/0.6070 TrainAcc/TestAcc: 0.9403/0.7444
# Epoch: [81/200] TrainLoss/TestLoss: 0.1471/0.7668 TrainAcc/TestAcc: 0.9507/0.7667
# Epoch: [91/200] TrainLoss/TestLoss: 0.1463/0.5775 TrainAcc/TestAcc: 0.9451/0.7722
# Epoch: [101/200] TrainLoss/TestLoss: 0.1182/0.7734 TrainAcc/TestAcc: 0.9646/0.7889
# Epoch: [111/200] TrainLoss/TestLoss: 0.1613/0.7574 TrainAcc/TestAcc: 0.9521/0.7500
# Epoch: [121/200] TrainLoss/TestLoss: 0.1135/0.6547 TrainAcc/TestAcc: 0.9618/0.8056
# Epoch: [131/200] TrainLoss/TestLoss: 0.1282/0.7216 TrainAcc/TestAcc: 0.9563/0.7944
# Epoch: [141/200] TrainLoss/TestLoss: 0.0641/1.0558 TrainAcc/TestAcc: 0.9736/0.7333
# Epoch: [151/200] TrainLoss/TestLoss: 0.0750/0.9764 TrainAcc/TestAcc: 0.9840/0.7722
# Epoch: [161/200] TrainLoss/TestLoss: 0.0457/1.0107 TrainAcc/TestAcc: 0.9875/0.7667
# Epoch: [171/200] TrainLoss/TestLoss: 0.0514/0.9220 TrainAcc/TestAcc: 0.9819/0.7722
# Epoch: [181/200] TrainLoss/TestLoss: 0.0661/1.1524 TrainAcc/TestAcc: 0.9806/0.7444
# Epoch: [191/200] TrainLoss/TestLoss: 0.0305/1.2342 TrainAcc/TestAcc: 0.9917/0.7611
# Epoch: [1/200] TrainLoss/TestLoss: 0.8658/0.7190 TrainAcc/TestAcc: 0.5069/0.5944
# Fold 5 Acc imporve from 0 to 0.5944444444444444 Save Model...
# Fold 5 Acc imporve from 0.5944444444444444 to 0.6888888888888888 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5769/0.5964 TrainAcc/TestAcc: 0.7111/0.6944
# Fold 5 Acc imporve from 0.6888888888888888 to 0.6944444444444443 Save Model...
# Fold 5 Acc imporve from 0.6944444444444443 to 0.7111111111111111 Save Model...
# Fold 5 Acc imporve from 0.7111111111111111 to 0.75 Save Model...
# Fold 5 Acc imporve from 0.75 to 0.8111111111111112 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4353/0.5206 TrainAcc/TestAcc: 0.8063/0.7778
# Fold 5 Acc imporve from 0.8111111111111112 to 0.8333333333333334 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3805/0.4034 TrainAcc/TestAcc: 0.8465/0.8333
# Fold 5 Acc imporve from 0.8333333333333334 to 0.8388888888888889 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.3055/0.4157 TrainAcc/TestAcc: 0.8799/0.8111
# Epoch: [51/200] TrainLoss/TestLoss: 0.2896/0.4471 TrainAcc/TestAcc: 0.8910/0.8000
# Fold 5 Acc imporve from 0.8388888888888889 to 0.8444444444444446 Save Model...
# Epoch: [61/200] TrainLoss/TestLoss: 0.2209/0.4258 TrainAcc/TestAcc: 0.9271/0.7944
# Fold 5 Acc imporve from 0.8444444444444446 to 0.85 Save Model...
# Fold 5 Acc imporve from 0.85 to 0.8555555555555556 Save Model...
# Epoch: [71/200] TrainLoss/TestLoss: 0.1994/0.4117 TrainAcc/TestAcc: 0.9264/0.8444
# Epoch: [81/200] TrainLoss/TestLoss: 0.1636/0.4703 TrainAcc/TestAcc: 0.9424/0.7889
# Epoch: [91/200] TrainLoss/TestLoss: 0.1581/0.4132 TrainAcc/TestAcc: 0.9569/0.8222
# Epoch: [101/200] TrainLoss/TestLoss: 0.1126/0.4126 TrainAcc/TestAcc: 0.9632/0.8444
# Fold 5 Acc imporve from 0.8555555555555556 to 0.8666666666666667 Save Model...
# Epoch: [111/200] TrainLoss/TestLoss: 0.1413/0.4771 TrainAcc/TestAcc: 0.9549/0.8111
# Epoch: [121/200] TrainLoss/TestLoss: 0.1250/0.5746 TrainAcc/TestAcc: 0.9556/0.7889
# Epoch: [131/200] TrainLoss/TestLoss: 0.0882/0.5459 TrainAcc/TestAcc: 0.9722/0.8222
# Epoch: [141/200] TrainLoss/TestLoss: 0.0751/0.6632 TrainAcc/TestAcc: 0.9792/0.7944
# Fold 5 Acc imporve from 0.8666666666666667 to 0.888888888888889 Save Model...
# Epoch: [151/200] TrainLoss/TestLoss: 0.0660/0.6909 TrainAcc/TestAcc: 0.9764/0.8167
# Epoch: [161/200] TrainLoss/TestLoss: 0.0440/0.5803 TrainAcc/TestAcc: 0.9882/0.8167
# Epoch: [171/200] TrainLoss/TestLoss: 0.1565/0.7137 TrainAcc/TestAcc: 0.9507/0.8000
# Epoch: [181/200] TrainLoss/TestLoss: 0.0691/0.6039 TrainAcc/TestAcc: 0.9764/0.8222
# Epoch: [191/200] TrainLoss/TestLoss: 0.0333/0.5880 TrainAcc/TestAcc: 0.9924/0.8222
# Epoch: [1/200] TrainLoss/TestLoss: 0.8249/0.7146 TrainAcc/TestAcc: 0.5146/0.5611
# Fold 6 Acc imporve from 0 to 0.561111111111111 Save Model...
# Fold 6 Acc imporve from 0.561111111111111 to 0.6611111111111111 Save Model...
# Fold 6 Acc imporve from 0.6611111111111111 to 0.7277777777777777 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5884/0.5939 TrainAcc/TestAcc: 0.6910/0.6611
# Fold 6 Acc imporve from 0.7277777777777777 to 0.7555555555555556 Save Model...
# Fold 6 Acc imporve from 0.7555555555555556 to 0.7611111111111111 Save Model...
# Fold 6 Acc imporve from 0.7611111111111111 to 0.8055555555555557 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4572/0.5488 TrainAcc/TestAcc: 0.8007/0.7389
# Epoch: [31/200] TrainLoss/TestLoss: 0.4058/0.6217 TrainAcc/TestAcc: 0.8479/0.7556
# Fold 6 Acc imporve from 0.8055555555555557 to 0.8277777777777778 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.3288/0.5261 TrainAcc/TestAcc: 0.8743/0.7944
# Fold 6 Acc imporve from 0.8277777777777778 to 0.8444444444444444 Save Model...
# Epoch: [51/200] TrainLoss/TestLoss: 0.2936/0.5427 TrainAcc/TestAcc: 0.8889/0.8056
# Fold 6 Acc imporve from 0.8444444444444444 to 0.8722222222222222 Save Model...
# Epoch: [61/200] TrainLoss/TestLoss: 0.2277/0.5380 TrainAcc/TestAcc: 0.9090/0.8278
# Epoch: [71/200] TrainLoss/TestLoss: 0.2228/0.5913 TrainAcc/TestAcc: 0.9174/0.7944
# Epoch: [81/200] TrainLoss/TestLoss: 0.1757/0.5964 TrainAcc/TestAcc: 0.9292/0.7944
# Epoch: [91/200] TrainLoss/TestLoss: 0.1950/0.7201 TrainAcc/TestAcc: 0.9250/0.7833
# Epoch: [101/200] TrainLoss/TestLoss: 0.1249/0.6034 TrainAcc/TestAcc: 0.9549/0.8222
# Epoch: [111/200] TrainLoss/TestLoss: 0.1324/0.7035 TrainAcc/TestAcc: 0.9479/0.8056
# Epoch: [121/200] TrainLoss/TestLoss: 0.0949/1.1863 TrainAcc/TestAcc: 0.9646/0.8222
# Epoch: [131/200] TrainLoss/TestLoss: 0.0924/1.3165 TrainAcc/TestAcc: 0.9688/0.8000
# Epoch: [141/200] TrainLoss/TestLoss: 0.0625/0.8694 TrainAcc/TestAcc: 0.9778/0.7889
# Epoch: [151/200] TrainLoss/TestLoss: 0.0615/0.6050 TrainAcc/TestAcc: 0.9826/0.8556
# Epoch: [161/200] TrainLoss/TestLoss: 0.0638/1.1737 TrainAcc/TestAcc: 0.9819/0.8111
# Epoch: [171/200] TrainLoss/TestLoss: 0.0619/0.9731 TrainAcc/TestAcc: 0.9785/0.8444
# Epoch: [181/200] TrainLoss/TestLoss: 0.0687/1.2164 TrainAcc/TestAcc: 0.9764/0.8000
# Epoch: [191/200] TrainLoss/TestLoss: 0.0492/0.6536 TrainAcc/TestAcc: 0.9799/0.8611
# Epoch: [1/200] TrainLoss/TestLoss: 0.8157/0.7266 TrainAcc/TestAcc: 0.5194/0.5000
# Fold 7 Acc imporve from 0 to 0.5 Save Model...
# Fold 7 Acc imporve from 0.5 to 0.5722222222222223 Save Model...
# Fold 7 Acc imporve from 0.5722222222222223 to 0.5888888888888889 Save Model...
# Fold 7 Acc imporve from 0.5888888888888889 to 0.6055555555555555 Save Model...
# Fold 7 Acc imporve from 0.6055555555555555 to 0.6388888888888888 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5941/0.6208 TrainAcc/TestAcc: 0.6799/0.6667
# Fold 7 Acc imporve from 0.6388888888888888 to 0.6666666666666666 Save Model...
# Fold 7 Acc imporve from 0.6666666666666666 to 0.7833333333333333 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4855/0.5267 TrainAcc/TestAcc: 0.7708/0.7889
# Fold 7 Acc imporve from 0.7833333333333333 to 0.7888888888888889 Save Model...
# Fold 7 Acc imporve from 0.7888888888888889 to 0.7944444444444444 Save Model...
# Fold 7 Acc imporve from 0.7944444444444444 to 0.7999999999999999 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3824/0.5195 TrainAcc/TestAcc: 0.8479/0.8167
# Fold 7 Acc imporve from 0.7999999999999999 to 0.8166666666666668 Save Model...
# Fold 7 Acc imporve from 0.8166666666666668 to 0.8277777777777778 Save Model...
# Fold 7 Acc imporve from 0.8277777777777778 to 0.8500000000000001 Save Model...
# Fold 7 Acc imporve from 0.8500000000000001 to 0.8777777777777779 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.3552/0.4865 TrainAcc/TestAcc: 0.8563/0.8111
# Epoch: [51/200] TrainLoss/TestLoss: 0.2779/0.5252 TrainAcc/TestAcc: 0.8896/0.8056
# Epoch: [61/200] TrainLoss/TestLoss: 0.2374/0.6165 TrainAcc/TestAcc: 0.9111/0.8000
# Epoch: [71/200] TrainLoss/TestLoss: 0.2696/0.7043 TrainAcc/TestAcc: 0.8993/0.8278
# Epoch: [81/200] TrainLoss/TestLoss: 0.1609/0.5465 TrainAcc/TestAcc: 0.9431/0.8556
# Epoch: [91/200] TrainLoss/TestLoss: 0.1595/0.7190 TrainAcc/TestAcc: 0.9396/0.8056
# Epoch: [101/200] TrainLoss/TestLoss: 0.1355/0.7897 TrainAcc/TestAcc: 0.9486/0.8444
# Epoch: [111/200] TrainLoss/TestLoss: 0.1220/0.9045 TrainAcc/TestAcc: 0.9507/0.8611
# Epoch: [121/200] TrainLoss/TestLoss: 0.0981/0.6289 TrainAcc/TestAcc: 0.9583/0.8389
# Epoch: [131/200] TrainLoss/TestLoss: 0.1004/0.8941 TrainAcc/TestAcc: 0.9701/0.8722
# Epoch: [141/200] TrainLoss/TestLoss: 0.0666/1.9650 TrainAcc/TestAcc: 0.9708/0.8500
# Epoch: [151/200] TrainLoss/TestLoss: 0.0884/0.7659 TrainAcc/TestAcc: 0.9667/0.8278
# Epoch: [161/200] TrainLoss/TestLoss: 0.0658/0.8641 TrainAcc/TestAcc: 0.9729/0.8333
# Epoch: [171/200] TrainLoss/TestLoss: 0.0715/1.0550 TrainAcc/TestAcc: 0.9736/0.8500
# Epoch: [181/200] TrainLoss/TestLoss: 0.0576/1.2355 TrainAcc/TestAcc: 0.9806/0.8444
# Epoch: [191/200] TrainLoss/TestLoss: 0.0473/0.8427 TrainAcc/TestAcc: 0.9840/0.8500
# Fold 7 Acc imporve from 0.8777777777777779 to 0.888888888888889 Save Model...
# Epoch: [1/200] TrainLoss/TestLoss: 0.8350/0.6906 TrainAcc/TestAcc: 0.5042/0.5111
# Fold 8 Acc imporve from 0 to 0.5111111111111111 Save Model...
# Fold 8 Acc imporve from 0.5111111111111111 to 0.6 Save Model...
# Fold 8 Acc imporve from 0.6 to 0.6222222222222221 Save Model...
# Fold 8 Acc imporve from 0.6222222222222221 to 0.6444444444444444 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.6139/0.6311 TrainAcc/TestAcc: 0.6694/0.6833
# Fold 8 Acc imporve from 0.6444444444444444 to 0.6833333333333332 Save Model...
# Fold 8 Acc imporve from 0.6833333333333332 to 0.7111111111111111 Save Model...
# Fold 8 Acc imporve from 0.7111111111111111 to 0.7333333333333334 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.5147/0.5712 TrainAcc/TestAcc: 0.7639/0.6833
# Fold 8 Acc imporve from 0.7333333333333334 to 0.7444444444444445 Save Model...
# Fold 8 Acc imporve from 0.7444444444444445 to 0.7777777777777777 Save Model...
# Fold 8 Acc imporve from 0.7777777777777777 to 0.7833333333333333 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.3923/0.4787 TrainAcc/TestAcc: 0.8250/0.7667
# Fold 8 Acc imporve from 0.7833333333333333 to 0.8277777777777778 Save Model...
# Fold 8 Acc imporve from 0.8277777777777778 to 0.8444444444444446 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.3618/0.4814 TrainAcc/TestAcc: 0.8493/0.7944
# Epoch: [51/200] TrainLoss/TestLoss: 0.3092/0.5180 TrainAcc/TestAcc: 0.8750/0.8000
# Epoch: [61/200] TrainLoss/TestLoss: 0.2475/0.5507 TrainAcc/TestAcc: 0.8979/0.8222
# Epoch: [71/200] TrainLoss/TestLoss: 0.2143/0.5126 TrainAcc/TestAcc: 0.9118/0.8333
# Fold 8 Acc imporve from 0.8444444444444446 to 0.8500000000000001 Save Model...
# Fold 8 Acc imporve from 0.8500000000000001 to 0.861111111111111 Save Model...
# Epoch: [81/200] TrainLoss/TestLoss: 0.1836/0.4733 TrainAcc/TestAcc: 0.9299/0.8389
# Fold 8 Acc imporve from 0.861111111111111 to 0.8722222222222223 Save Model...
# Epoch: [91/200] TrainLoss/TestLoss: 0.1620/0.6197 TrainAcc/TestAcc: 0.9410/0.7944
# Epoch: [101/200] TrainLoss/TestLoss: 0.1526/0.5336 TrainAcc/TestAcc: 0.9417/0.8333
# Epoch: [111/200] TrainLoss/TestLoss: 0.2263/0.5040 TrainAcc/TestAcc: 0.9313/0.8111
# Epoch: [121/200] TrainLoss/TestLoss: 0.1790/0.5857 TrainAcc/TestAcc: 0.9403/0.8111
# Epoch: [131/200] TrainLoss/TestLoss: 0.1136/0.7948 TrainAcc/TestAcc: 0.9569/0.8167
# Epoch: [141/200] TrainLoss/TestLoss: 0.0850/0.6230 TrainAcc/TestAcc: 0.9660/0.8444
# Epoch: [151/200] TrainLoss/TestLoss: 0.0691/0.6219 TrainAcc/TestAcc: 0.9757/0.8333
# Epoch: [161/200] TrainLoss/TestLoss: 0.0654/0.7987 TrainAcc/TestAcc: 0.9750/0.8167
# Epoch: [171/200] TrainLoss/TestLoss: 0.0603/0.6666 TrainAcc/TestAcc: 0.9771/0.8056
# Epoch: [181/200] TrainLoss/TestLoss: 0.0800/0.9668 TrainAcc/TestAcc: 0.9715/0.8389
# Epoch: [191/200] TrainLoss/TestLoss: 0.0563/1.2800 TrainAcc/TestAcc: 0.9792/0.7944
# Epoch: [1/200] TrainLoss/TestLoss: 0.8713/0.7154 TrainAcc/TestAcc: 0.4986/0.5444
# Fold 9 Acc imporve from 0 to 0.5444444444444444 Save Model...
# Fold 9 Acc imporve from 0.5444444444444444 to 0.55 Save Model...
# Fold 9 Acc imporve from 0.55 to 0.5944444444444444 Save Model...
# Fold 9 Acc imporve from 0.5944444444444444 to 0.6222222222222222 Save Model...
# Fold 9 Acc imporve from 0.6222222222222222 to 0.6333333333333333 Save Model...
# Epoch: [11/200] TrainLoss/TestLoss: 0.5918/0.5881 TrainAcc/TestAcc: 0.6778/0.7167
# Fold 9 Acc imporve from 0.6333333333333333 to 0.7166666666666667 Save Model...
# Fold 9 Acc imporve from 0.7166666666666667 to 0.7222222222222222 Save Model...
# Fold 9 Acc imporve from 0.7222222222222222 to 0.7722222222222221 Save Model...
# Fold 9 Acc imporve from 0.7722222222222221 to 0.7833333333333333 Save Model...
# Epoch: [21/200] TrainLoss/TestLoss: 0.4778/0.4652 TrainAcc/TestAcc: 0.7792/0.8000
# Fold 9 Acc imporve from 0.7833333333333333 to 0.8000000000000002 Save Model...
# Fold 9 Acc imporve from 0.8000000000000002 to 0.827777777777778 Save Model...
# Epoch: [31/200] TrainLoss/TestLoss: 0.4254/0.4021 TrainAcc/TestAcc: 0.8194/0.8333
# Fold 9 Acc imporve from 0.827777777777778 to 0.8333333333333334 Save Model...
# Fold 9 Acc imporve from 0.8333333333333334 to 0.8444444444444444 Save Model...
# Epoch: [41/200] TrainLoss/TestLoss: 0.3452/0.4477 TrainAcc/TestAcc: 0.8708/0.8167
# Fold 9 Acc imporve from 0.8444444444444444 to 0.85 Save Model...
# Fold 9 Acc imporve from 0.85 to 0.8500000000000001 Save Model...
# Epoch: [51/200] TrainLoss/TestLoss: 0.3061/0.5563 TrainAcc/TestAcc: 0.8785/0.8056
# Epoch: [61/200] TrainLoss/TestLoss: 0.2766/0.5336 TrainAcc/TestAcc: 0.8882/0.8056
# Fold 9 Acc imporve from 0.8500000000000001 to 0.8555555555555556 Save Model...
# Fold 9 Acc imporve from 0.8555555555555556 to 0.8666666666666667 Save Model...
# Epoch: [71/200] TrainLoss/TestLoss: 0.2120/0.4768 TrainAcc/TestAcc: 0.9097/0.8333
# Epoch: [81/200] TrainLoss/TestLoss: 0.1998/0.5178 TrainAcc/TestAcc: 0.9208/0.7944
# Epoch: [91/200] TrainLoss/TestLoss: 0.1624/0.6114 TrainAcc/TestAcc: 0.9347/0.7889
# Epoch: [101/200] TrainLoss/TestLoss: 0.1403/0.6305 TrainAcc/TestAcc: 0.9500/0.8222
# Fold 9 Acc imporve from 0.8666666666666667 to 0.8833333333333334 Save Model...
# Epoch: [111/200] TrainLoss/TestLoss: 0.1584/0.6395 TrainAcc/TestAcc: 0.9431/0.8389
# Epoch: [121/200] TrainLoss/TestLoss: 0.1014/0.7118 TrainAcc/TestAcc: 0.9646/0.8222
# Fold 9 Acc imporve from 0.8833333333333334 to 0.9055555555555556 Save Model...
# Epoch: [131/200] TrainLoss/TestLoss: 0.0769/0.7404 TrainAcc/TestAcc: 0.9736/0.8444
# Epoch: [141/200] TrainLoss/TestLoss: 0.0923/0.6146 TrainAcc/TestAcc: 0.9688/0.8500
# Epoch: [151/200] TrainLoss/TestLoss: 0.1051/0.7851 TrainAcc/TestAcc: 0.9618/0.8111
# Epoch: [161/200] TrainLoss/TestLoss: 0.1129/0.6651 TrainAcc/TestAcc: 0.9611/0.8278
# Epoch: [171/200] TrainLoss/TestLoss: 0.0671/1.0461 TrainAcc/TestAcc: 0.9757/0.8167
# Epoch: [181/200] TrainLoss/TestLoss: 0.0942/0.8197 TrainAcc/TestAcc: 0.9715/0.8722
# Epoch: [191/200] TrainLoss/TestLoss: 0.0462/1.0645 TrainAcc/TestAcc: 0.9861/0.8333

# %%
test_perd = np.zeros(len(test_mat))
tta_count = 20

for fold_idx in range(10):
    Test_Loader = DataLoader(MyDataset(test_mat, paddle.to_tensor([0]*len(test_mat))), 
                    batch_size=BATCH_SIZE, shuffle=False)

    layer_state_dict = paddle.load(f"model_{fold_idx}.pdparams")
    model.set_state_dict(layer_state_dict)
    
    for tta in range(tta_count):
        test_pred_list = []
        for i, (x, y) in enumerate(Test_Loader):
            if device == 'gpu':
                x = x.cuda()
                y = y.cuda()
            
            pred = model(x)
            test_pred_list.append(
                paddle.nn.functional.sigmoid(pred).numpy()
            )

        test_perd += np.vstack(test_pred_list)[:, 0]
        
test_perd /= tta_count * 10

# %%
test_path = glob.glob('./val/*.mat')
test_path = [os.path.basename(x)[:-4] for x in test_path]
test_path.sort()

test_answer = pd.DataFrame({
    'name': test_path,
    'tag': (test_perd > 0.5).astype(int)
}).to_csv('answer.csv', index=None)

# !rm -rf  answer.csv.zip
# !zip answer.csv.zip answer.csv
# Out:
#   adding: answer.csv (deflated 80%)
